# %%
pip install pandas numpy matplotlib scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

print("✅ DATA ANALYTICS ENVIRONMENT FULLY READY!")
# Out:
# ✅ DATA ANALYTICS ENVIRONMENT FULLY READY!

# %%
df = pd.read_csv("customer_churn_records.csv")

# %%
df.head()
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0  XXXX-10055-XX  Female           Yes     Yes         No      77
# 1  XXXX-10117-XX  Female           Yes      No         No       2
# 2  XXXX-10206-XX    Male           Yes     Yes         No      34
# 3  XXXX-10235-XX  Female            No     Yes         No      16
# 4  XXXX-10301-XX  Female           Yes     Yes        Yes      74
#
#   PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 0           No           Yes     Fiber optic  No internet service  ...
# 1          Yes           Yes             DSL                  Yes  ...
# 2           No            No              No                   No  ...
# 3           No            No              No                  Yes  ...
# 4          Yes            No             DSL                   No  ...
#
#   DeviceProtection TechSupport          StreamingTV      StreamingMovies  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        996 non-null    object
#  1   gender            996 non-null    object
#  2   SeniorCitizen     996 non-null    object
#  3   Partner           996 non-null    object
#  4   Dependents        996 non-null    object
#  5   tenure            996 non-null    int64
#  6   PhoneService      996 non-null    object
#  7   MultipleLines     996 non-null    object
#  8   InternetService   996 non-null    object
#  9   OnlineSecurity    996 non-null    object
#  10  OnlineBackup      996 non-null    object
#  11  DeviceProtection  996 non-null    object
#  12  TechSupport       996 non-null    object
#  13  StreamingTV       996 non-null    object
#  14  StreamingMovies   996 non-null    object
#  15  Contract          996 non-null    object
# ...

# %%
df.describe()
# Out:
#            tenure  MonthlyCharges  TotalCharges
# count  996.000000      996.000000    996.000000
# mean    40.546185       69.743986   4468.034749
# std     22.750755       30.275531   2593.709828
# min      0.000000       18.020000     30.810000
# 25%     21.000000       43.855000   2205.910000
# 50%     41.000000       68.540000   4403.090000
# 75%     60.000000       97.265000   6751.847500
# max     79.000000      119.930000   8988.310000

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.columns = [col.title() for col in df.columns]

# %%
# snake_case
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
# Handle Online / Service columns (keep 3 categories: Yes, No, No internet service / No phone service)
service_cols = ['multiple_lines', 'internet_service', 'online_security', 'online_backup',
                'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies']

# %%
# Standardize Contract column
df['contract'] = df['contract'].str.strip().replace({
    'month to month': 'Month-to-month',
    '1 year': 'One year',
    '2 year': 'Two year'
})

# %%
# install required packages for SQLAlchemy + PostgreSQL driver
# %pip install sqlalchemy psycopg2-binary

from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = 'postgres'
password = quote_plus('Himasha@1977') 
host = 'localhost'
port = '5432'
database = 'customer_churn'

engine = create_engine(
    f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}'
)

table_name = 'churn_data'
df.to_sql(table_name, engine, if_exists='replace', index=False)

print(f"✅ DataFrame successfully loaded into '{table_name}' in database '{database}'.")
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached psycopg2_binary-2.9.11-cp314-cp314-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
# ...
